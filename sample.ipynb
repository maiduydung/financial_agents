# %%
from tavily import TavilyClient

tavily_client = TavilyClient(api_key="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")
response = tavily_client.extract("pathfindersoftworks.com")

print(response)
# Out:
# {'results': [{'url': 'https://pathfindersoftworks.com', 'title': 'Pathfinder Softworks - We Build Software That Delivers Results', 'raw_content': "![Pathfinder Softworks](/logo/pathfinder_softworks.png)\n\nFull-service software agency\n\n# We build software that delivers results.\n\nA team across 3 continents with FAANG alumni, Sam Altman-backed founders, and engineers who've shipped production systems at scale. We build SaaS platforms, data pipelines, and AI products that save you time, cut costs, and drive real ROI.\n\n## Projects we delivered\n\nEvery project here solved a real business problem and produced a measurable outcome.\n\n### Proplytics\n\nThe only platform that surfaces ROI, cash flow, cap rate, and rent-to-price ratios for 140M+ US properties, updated daily. 97.5% of listings have full financial metrics, coverage that even Zillow doesn't offer. Used by thousands of investors and agents, generating real revenue, backed by Sam Altman's Residency program.\n\n140M+\n\nProp
# ...
